# %%
import pandas as pd
dfp=pd.read_csv("/content/parkinsons.csv")
dfp
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
# !pip install lazypredict
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 703.4/703.4 kB 41.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 18.7 MB/s eta 0:00:00
# ...

# %%
# !pip install imbalanced-learn

# %%
# 1️⃣ Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from lazypredict.Supervised import LazyClassifier

# 2️⃣ Separate features and target
X = dfp.drop(columns=['name', 'status'])
y = dfp['status']

# 3️⃣ Balance the dataset using random undersampling
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

print("Class distribution after undersampling:")
print(pd.Series(y_res).value_counts())

# 4️⃣ Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res
)

# 5️⃣ Use LazyPredict to check model accuracies
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# 6️⃣ Show model comparison
print(models)
# Out:
# Class distribution after undersampling:
# status
# 0    48
# 1    48
# Name: count, dtype: int64
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 38, number of negative: 38
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 569
# [LightGBM] [Info] Number of data points in the train set: 76, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
import pandas as pd
df_kid_filled=pd.read_csv("/content/df_kid_filled.csv")
df_kid_filled
# Out:
#         id   age    bp   sg   al   su  rbc   pc  pcc   ba  ...   pcv      wc  \
# 0     0.00 48.00 80.00 1.02 1.00 0.00 0.20 1.00 0.00 0.00  ... 44.00 7800.00
# 1     1.00  7.00 50.00 1.02 4.00 0.00 0.40 1.00 0.00 0.00  ... 38.00 6000.00
# 2     2.00 62.00 80.00 1.01 2.00 3.00 1.00 1.00 0.00 0.00  ... 31.00 7500.00
# 3     3.00 48.00 70.00 1.00 4.00 0.00 1.00 0.00 1.00 0.00  ... 32.00 6700.00
# 4     4.00 51.00 80.00 1.01 2.00 0.00 1.00 1.00 0.00 0.00  ... 35.00 7300.00
# ..     ...   ...   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...     ...
# 395 395.00 55.00 80.00 1.02 0.00 0.00 1.00 1.00 0.00 0.00  ... 47.00 6700.00
# 396 396.00 42.00 70.00 1.02 0.00 0.00 1.00 1.00 0.00 0.00  ... 54.00 7800.00
# 397 397.00 12.00 80.00 1.02 0.00 0.00 1.00 1.00 0.00 0.00  ... 49.00 6600.00
# 398 398.00 17.00 60.00 1.02 0.00 0.00 1.00 1.00 0.00 0.00  ... 51.00 7200.00
# 399 399.00 58.00 80.00 1.02 0.00 0.00 1.00 1.00 0.00 0.00  ... 53.00 6800.00
#
# ...

# %%
# 1️⃣ Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from lazypredict.Supervised import LazyClassifier

# 2️⃣ Separate features and target
X = df_kid_filled.drop(columns=['id', 'age', 'classification'])
y = df_kid_filled['classification']

# 3️⃣ Balance the dataset using RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

# 4️⃣ Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res
)

# 5️⃣ Initialize LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# 6️⃣ Fit on training data and evaluate
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# 7️⃣ See the results
print(models)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 120, number of negative: 120
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 481
# [LightGBM] [Info] Number of data points in the train set: 240, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
import pandas as pd
df_lvr_filled=pd.read_csv("/content/df_lvr_filled.csv")
df_lvr_filled
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female             0.70              0.10                   187
# 1     62    Male            10.90              5.50                   699
# 2     62    Male             7.30              4.10                   490
# 3     58    Male             1.00              0.40                   182
# 4     72    Male             3.90              2.00                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male             0.50              0.10                   500
# 579   40    Male             0.60              0.10                    98
# 580   52    Male             0.80              0.20                   245
# 581   31    Male             1.30              0.50                   184
# 582   38    Male             1.00              0.30                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
# 1️⃣ Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from lazypredict.Supervised import LazyClassifier

# 2️⃣ Separate features and target
X = df_lvr_filled.drop(columns=['Age', 'Gender', 'Dataset'])
y = df_lvr_filled['Dataset']

# 3️⃣ Balance the dataset using RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X, y)

# 4️⃣ Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42, stratify=y_res
)

# 5️⃣ Initialize LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# 6️⃣ Fit on training data and evaluate
models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# 7️⃣ See the results
print(models)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 134, number of negative: 133
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000076 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 347
# [LightGBM] [Info] Number of data points in the train set: 267, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501873 -> initscore=0.007491
# [LightGBM] [Info] Start training from score 0.007491
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
df_kid_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    float64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              400 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   rbc             400 non-null    float64
#  7   pc              400 non-null    float64
#  8   pcc             400 non-null    float64
#  9   ba              400 non-null    float64
#  10  bgr             400 non-null    float64
#  11  bu              400 non-null    float64
#  12  sc              400 non-null    float64
#  13  sod             400 non-null    float64
#  14  pot             400 non-null    float64
#  15  hemo            400 non-null    float64
#  16  pcv             400 non-null    float64
# ...
